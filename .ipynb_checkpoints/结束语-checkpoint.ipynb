# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("visual-question-answering", model="dandelin/vilt-b32-finetuned-vqa")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/136k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.

# %%
pipe({"image":"https://free-images.com/md/7687/blue_jay_bird_nature.jpg",
      "question":"What's the animal in the image?"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pipe({"image":"https://free-images.com/md/7687/blue_jay_bird_nature.jpg",
#       2       "questioin":"What's the animal in the image?"})
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/visual_question_answering.py:109, in VisualQuestionAnsweringPipeline.__call__(self, image, question, **kwargs)
#     102     """
#     103     Supports the following format
#     104     - {"image": image, "question": question}
#     105     - [{"image": image, "question": question}]
#     106     - Generator and datasets
#     107     """
#     108     inputs = image
# --> 109 results = super().__call__(inputs, **kwargs)
#     110 return results
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/base.py:1119, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1111     return next(
#    1112         iter(
#    1113             self.get_iterator(
#    (...)
#    1116         )
#    1117     )
#    1118 else:
# -> 1119     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/base.py:1125, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1124 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
# -> 1125     model_inputs = self.preprocess(inputs, **preprocess_params)
#    1126     model_outputs = self.forward(model_inputs, **forward_params)
#    1127     outputs = self.postprocess(model_outputs, **postprocess_params)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/visual_question_answering.py:115, in VisualQuestionAnsweringPipeline.preprocess(self, inputs, padding, truncation)
#     112 def preprocess(self, inputs, padding=False, truncation=False):
#     113     image = load_image(inputs["image"])
#     114     model_inputs = self.tokenizer(
# --> 115         inputs["question"], return_tensors=self.framework, padding=padding, truncation=truncation
#     116     )
#     117     image_features = self.image_processor(images=image, return_tensors=self.framework)
#     118     model_inputs.update(image_features)
#
# KeyError: 'question'
